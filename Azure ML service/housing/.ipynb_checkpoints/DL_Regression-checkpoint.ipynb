# %% [markdown]
# ## House Prices Prediction
#
# ### In this tutorial we will prepare a dataset with houses characteristics and selling prices and train a regression model for sales price prediction.
#
# #### The dataset to be used is the [Ames Housing Dataset](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data) from Kaggle, which has variables describing (almost) every aspect of residential homes in Ames, Iowa.
#
# #### Usually in a problem like this, one would explore the data and apply a fair amount of feature engineering to construct a training dataset for some more traditional multivariate regression algorithm. But here we will use a different approach, based on a Deep Neural Network that tries to learn good feature representations while being trained for the regression problem. We call this an end-to-end approach.
#
# #### For that, we are going to apply a technique known as [Deep Learning for Tabular Data](https://www.fast.ai/2018/04/29/categorical-embeddings/), also known as "Structured Deep Learning". The main idea here is to represent categorical variables in a (dense) [embedding space](https://en.wikipedia.org/wiki/Embedding), instead of the usual [One-Hot Encoding](https://en.wikipedia.org/wiki/One-hot). This embedding space is usually parameterized by a weight matrix, which in our case will be learned end-to-end with the regression problem.
#
# #### In a Deep Learning setup, this allows a model to learn useful concepts and relations between features. For a toy example, suppose you have a variable representing day-of-week.
#
# #### For the values "Sunday", "Monday", and "Tuesday" there would be an one-hot-encodding representation like this:
# | day     | b1 | b2 | b3 | b4 | b5 | b6 | b7 |
# |---------|----|----|----|----|----|----|----|
# | Sunday  | 1  | 0  | 0  | 0  | 0  | 0  | 0  |
# | Monday  | 0  | 1  | 0  | 0  | 0  | 0  | 0  |
# | Tuesday | 0  | 0  | 1  | 0  | 0  | 0  | 0  |
#
# #### Now suppose you train an embedding layer of size 3 for this variable, end-to-end. Your model could then learn something like this:
# | day     | e1  | e2  | e3  | e4  |
# |---------|-----|-----|-----|-----|
# | Sunday  | 0.8 | 0.2 | 0.1 | 0.1 |
# | Monday  | 0.1 | 0.2 | 0.9 | 0.9 |
# | Tuesday | 0.2 | 0.1 | 0.9 | 0.8 |
#
# #### Notice that while the one-hot encoding representation does not capture anything interesting about the data, the learned embeddings might capture a useful concept like being a weekday or not. In the example above, we see that the vectors representing Monday and Tuesday are closer to each other than the vector representing Sunday, and the first dimension of the embedding vector could represent that concept of a weekday.
#
# #### We will begin by analyzing the dataset and performing a very basic preparation, like dealing with missing values and correcting data types for the variables. We then will construct and train a deep neural network for regression, using the [PyTorch](https://pytorch.org/) framework, that learns to predict house prices.
#
# #### The purpose of this notebook is to explain the concepts described here in a more friendly manner. We will then perform the same training process defined here in the cloud, in a scalable manner using a cluster of GPUs and show the power of the Hyperdrive functionality of Azure Machine Learning service for hyperparameter tuning.
#
# #### <font color='red'> Before you begin: please download the training dataset from Kaggle and save it into the "data" folder as "train.csv". You will need to login into Kaggle to be able to download the dataset. </font>

# %% [markdown]
# #### We begin by importing the necessary packages.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Normalizer
import matplotlib.pyplot as plt
import pickle

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %% [markdown]
# #### We then load the dataset into a Pandas data frame, visualize the first 10 rows, and print the total number of rows and columns. We notice that this dataset has 1460 rows and 81 columns. Our response variable is the column named "SalePrice".

# %%
df_housing = pd.read_csv("./data/train.csv")

# %%
df_housing.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 5         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 7         Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 8         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 9         Lvl    AllPub    Corner       Gtl      BrkSide     Artery
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
# 5       Norm     1Fam     1.5Fin            5            5       1993
# 6       Norm     1Fam     1Story            8            5       2004
# 7       Norm     1Fam     2Story            7            6       1973
# 8       Norm     1Fam     1.5Fin            7            5       1931
# 9     Artery   2fmCon     1.5Unf            5            6       1939
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 5          1995     Gable  CompShg     VinylSd     VinylSd       None
# 6          2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 7          1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 8          1950     Gable  CompShg     BrkFace     Wd Shng       None
# 9          1950     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
# 5         0.0        TA        TA       Wood       Gd       TA           No
# 6       186.0        Gd        TA      PConc       Ex       TA           Av
# 7       240.0        TA        TA     CBlock       Gd       TA           Mn
# 8         0.0        TA        TA     BrkTil       TA       TA           No
# 9         0.0        TA        TA     BrkTil       TA       TA           No
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
# 5          GLQ         732          Unf           0         64          796
# 6          GLQ        1369          Unf           0        317         1686
# 7          ALQ         859          BLQ          32        216         1107
# 8          Unf           0          Unf           0        952          952
# 9          GLQ         851          Unf           0        140          991
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
# 5    GasA        Ex          Y      SBrkr       796       566             0
# 6    GasA        Ex          Y      SBrkr      1694         0             0
# 7    GasA        Ex          Y      SBrkr      1107       983             0
# 8    GasA        Gd          Y      FuseF      1022       752             0
# 9    GasA        Ex          Y      SBrkr      1077         0             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
# 5       1362             1             0         1         1             1
# 6       1694             1             0         2         0             3
# 7       2090             1             0         2         1             3
# 8       1774             0             0         2         0             2
# 9       1077             1             0         1         0             2
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
# 5             1          TA             5        Typ           0         NaN
# 6             1          Gd             7        Typ           1          Gd
# 7             1          TA             7        Typ           2          TA
# 8             2          TA             8       Min1           2          TA
# 9             2          TA             5        Typ           2          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
# 5     Attchd       1993.0          Unf           2         480         TA
# 6     Attchd       2004.0          RFn           2         636         TA
# 7     Attchd       1973.0          RFn           2         484         TA
# 8     Detchd       1931.0          Unf           2         468         Fa
# 9     Attchd       1939.0          RFn           1         205         Gd
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
# 5         TA          Y          40           30              0        320
# 6         TA          Y         255           57              0          0
# 7         TA          Y         235          204            228          0
# 8         TA          Y          90            0            205          0
# 9         TA          Y           0            4              0          0
#
#    ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN    NaN         NaN        0       2    2008
# 1            0         0    NaN    NaN         NaN        0       5    2007
# 2            0         0    NaN    NaN         NaN        0       9    2008
# 3            0         0    NaN    NaN         NaN        0       2    2006
# 4            0         0    NaN    NaN         NaN        0      12    2008
# 5            0         0    NaN  MnPrv        Shed      700      10    2009
# 6            0         0    NaN    NaN         NaN        0       8    2007
# 7            0         0    NaN    NaN        Shed      350      11    2009
# 8            0         0    NaN    NaN         NaN        0       4    2008
# 9            0         0    NaN    NaN         NaN        0       1    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000
# 5       WD        Normal     143000
# 6       WD        Normal     307000
# 7       WD        Normal     200000
# 8       WD       Abnorml     129900
# 9       WD        Normal     118000

# %%
df_housing.shape
# Out:
# (1460, 81)

# %% [markdown]
# #### We drop the "Id" column, because it will not help to predict the price. Then we describe all columns and notice several things:
# #### - the majority of the variables are categorical
# #### - some categorical variables are wrongly encoded as numerical
# #### - some numerical variables are wrongly encoded as categorical
# #### - there are several missing values

# %%
df_housing.drop("Id", axis = 1, inplace = True)

# %%
df_housing.describe(include = "all")
# Out:
#          MSSubClass MSZoning  LotFrontage        LotArea Street Alley  \
# count   1460.000000     1460  1201.000000    1460.000000   1460    91
# unique          NaN        5          NaN            NaN      2     2
# top             NaN       RL          NaN            NaN   Pave  Grvl
# freq            NaN     1151          NaN            NaN   1454    50
# mean      56.897260      NaN    70.049958   10516.828082    NaN   NaN
# std       42.300571      NaN    24.284752    9981.264932    NaN   NaN
# min       20.000000      NaN    21.000000    1300.000000    NaN   NaN
# 25%       20.000000      NaN    59.000000    7553.500000    NaN   NaN
# 50%       50.000000      NaN    69.000000    9478.500000    NaN   NaN
# 75%       70.000000      NaN    80.000000   11601.500000    NaN   NaN
# max      190.000000      NaN   313.000000  215245.000000    NaN   NaN
#
#        LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# count      1460        1460      1460      1460      1460         1460
# unique        4           4         2         5         3           25
# top         Reg         Lvl    AllPub    Inside       Gtl        NAmes
# freq        925        1311      1459      1052      1382          225
# mean        NaN         NaN       NaN       NaN       NaN          NaN
# std         NaN         NaN       NaN       NaN       NaN          NaN
# min         NaN         NaN       NaN       NaN       NaN          NaN
# 25%         NaN         NaN       NaN       NaN       NaN          NaN
# 50%         NaN         NaN       NaN       NaN       NaN          NaN
# 75%         NaN         NaN       NaN       NaN       NaN          NaN
# max         NaN         NaN       NaN       NaN       NaN          NaN
#
#        Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# count        1460       1460     1460       1460  1460.000000  1460.000000
# unique          9          8        5          8          NaN          NaN
# top          Norm       Norm     1Fam     1Story          NaN          NaN
# freq         1260       1445     1220        726          NaN          NaN
# mean          NaN        NaN      NaN        NaN     6.099315     5.575342
# std           NaN        NaN      NaN        NaN     1.382997     1.112799
# min           NaN        NaN      NaN        NaN     1.000000     1.000000
# 25%           NaN        NaN      NaN        NaN     5.000000     5.000000
# 50%           NaN        NaN      NaN        NaN     6.000000     5.000000
# 75%           NaN        NaN      NaN        NaN     7.000000     6.000000
# max           NaN        NaN      NaN        NaN    10.000000     9.000000
#
#           YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# count   1460.000000   1460.000000      1460     1460        1460        1460
# unique          NaN           NaN         6        8          15          16
# top             NaN           NaN     Gable  CompShg     VinylSd     VinylSd
# freq            NaN           NaN      1141     1434         515         504
# mean    1971.267808   1984.865753       NaN      NaN         NaN         NaN
# std       30.202904     20.645407       NaN      NaN         NaN         NaN
# min     1872.000000   1950.000000       NaN      NaN         NaN         NaN
# 25%     1954.000000   1967.000000       NaN      NaN         NaN         NaN
# 50%     1973.000000   1994.000000       NaN      NaN         NaN         NaN
# 75%     2000.000000   2004.000000       NaN      NaN         NaN         NaN
# max     2010.000000   2010.000000       NaN      NaN         NaN         NaN
#
#        MasVnrType   MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# count        1452  1452.000000      1460      1460       1460     1423
# unique          4          NaN         4         5          6        4
# top          None          NaN        TA        TA      PConc       TA
# freq          864          NaN       906      1282        647      649
# mean          NaN   103.685262       NaN       NaN        NaN      NaN
# std           NaN   181.066207       NaN       NaN        NaN      NaN
# min           NaN     0.000000       NaN       NaN        NaN      NaN
# 25%           NaN     0.000000       NaN       NaN        NaN      NaN
# 50%           NaN     0.000000       NaN       NaN        NaN      NaN
# 75%           NaN   166.000000       NaN       NaN        NaN      NaN
# max           NaN  1600.000000       NaN       NaN        NaN      NaN
#
#        BsmtCond BsmtExposure BsmtFinType1   BsmtFinSF1 BsmtFinType2  \
# count      1423         1422         1423  1460.000000         1422
# unique        4            4            6          NaN            6
# top          TA           No          Unf          NaN          Unf
# freq       1311          953          430          NaN         1256
# mean        NaN          NaN          NaN   443.639726          NaN
# std         NaN          NaN          NaN   456.098091          NaN
# min         NaN          NaN          NaN     0.000000          NaN
# 25%         NaN          NaN          NaN     0.000000          NaN
# 50%         NaN          NaN          NaN   383.500000          NaN
# 75%         NaN          NaN          NaN   712.250000          NaN
# max         NaN          NaN          NaN  5644.000000          NaN
#
#          BsmtFinSF2    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# count   1460.000000  1460.000000  1460.000000    1460      1460       1460
# unique          NaN          NaN          NaN       6         5          2
# top             NaN          NaN          NaN    GasA        Ex          Y
# freq            NaN          NaN          NaN    1428       741       1365
# mean      46.549315   567.240411  1057.429452     NaN       NaN        NaN
# std      161.319273   441.866955   438.705324     NaN       NaN        NaN
# min        0.000000     0.000000     0.000000     NaN       NaN        NaN
# 25%        0.000000   223.000000   795.750000     NaN       NaN        NaN
# 50%        0.000000   477.500000   991.500000     NaN       NaN        NaN
# 75%        0.000000   808.000000  1298.250000     NaN       NaN        NaN
# max     1474.000000  2336.000000  6110.000000     NaN       NaN        NaN
#
#        Electrical     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  \
# count        1459  1460.000000  1460.000000   1460.000000  1460.000000
# unique          5          NaN          NaN           NaN          NaN
# top         SBrkr          NaN          NaN           NaN          NaN
# freq         1334          NaN          NaN           NaN          NaN
# mean          NaN  1162.626712   346.992466      5.844521  1515.463699
# std           NaN   386.587738   436.528436     48.623081   525.480383
# min           NaN   334.000000     0.000000      0.000000   334.000000
# 25%           NaN   882.000000     0.000000      0.000000  1129.500000
# 50%           NaN  1087.000000     0.000000      0.000000  1464.000000
# 75%           NaN  1391.250000   728.000000      0.000000  1776.750000
# max           NaN  4692.000000  2065.000000    572.000000  5642.000000
#
#         BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  \
# count    1460.000000   1460.000000  1460.000000  1460.000000   1460.000000
# unique           NaN           NaN          NaN          NaN           NaN
# top              NaN           NaN          NaN          NaN           NaN
# freq             NaN           NaN          NaN          NaN           NaN
# mean        0.425342      0.057534     1.565068     0.382877      2.866438
# std         0.518911      0.238753     0.550916     0.502885      0.815778
# min         0.000000      0.000000     0.000000     0.000000      0.000000
# 25%         0.000000      0.000000     1.000000     0.000000      2.000000
# 50%         0.000000      0.000000     2.000000     0.000000      3.000000
# 75%         1.000000      0.000000     2.000000     1.000000      3.000000
# max         3.000000      2.000000     3.000000     2.000000      8.000000
#
#         KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional   Fireplaces  \
# count    1460.000000        1460   1460.000000       1460  1460.000000
# unique           NaN           4           NaN          7          NaN
# top              NaN          TA           NaN        Typ          NaN
# freq             NaN         735           NaN       1360          NaN
# mean        1.046575         NaN      6.517808        NaN     0.613014
# std         0.220338         NaN      1.625393        NaN     0.644666
# min         0.000000         NaN      2.000000        NaN     0.000000
# 25%         1.000000         NaN      5.000000        NaN     0.000000
# 50%         1.000000         NaN      6.000000        NaN     1.000000
# 75%         1.000000         NaN      7.000000        NaN     1.000000
# max         3.000000         NaN     14.000000        NaN     3.000000
#
#        FireplaceQu GarageType  GarageYrBlt GarageFinish   GarageCars  \
# count          770       1379  1379.000000         1379  1460.000000
# unique           5          6          NaN            3          NaN
# top             Gd     Attchd          NaN          Unf          NaN
# freq           380        870          NaN          605          NaN
# mean           NaN        NaN  1978.506164          NaN     1.767123
# std            NaN        NaN    24.689725          NaN     0.747315
# min            NaN        NaN  1900.000000          NaN     0.000000
# 25%            NaN        NaN  1961.000000          NaN     1.000000
# 50%            NaN        NaN  1980.000000          NaN     2.000000
# 75%            NaN        NaN  2002.000000          NaN     2.000000
# max            NaN        NaN  2010.000000          NaN     4.000000
#
#          GarageArea GarageQual GarageCond PavedDrive   WoodDeckSF  \
# count   1460.000000       1379       1379       1460  1460.000000
# unique          NaN          5          5          3          NaN
# top             NaN         TA         TA          Y          NaN
# freq            NaN       1311       1326       1340          NaN
# mean     472.980137        NaN        NaN        NaN    94.244521
# std      213.804841        NaN        NaN        NaN   125.338794
# min        0.000000        NaN        NaN        NaN     0.000000
# 25%      334.500000        NaN        NaN        NaN     0.000000
# 50%      480.000000        NaN        NaN        NaN     0.000000
# 75%      576.000000        NaN        NaN        NaN   168.000000
# max     1418.000000        NaN        NaN        NaN   857.000000
#
#         OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea  \
# count   1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# unique          NaN            NaN          NaN          NaN          NaN
# top             NaN            NaN          NaN          NaN          NaN
# freq            NaN            NaN          NaN          NaN          NaN
# mean      46.660274      21.954110     3.409589    15.060959     2.758904
# std       66.256028      61.119149    29.317331    55.757415    40.177307
# min        0.000000       0.000000     0.000000     0.000000     0.000000
# 25%        0.000000       0.000000     0.000000     0.000000     0.000000
# 50%       25.000000       0.000000     0.000000     0.000000     0.000000
# 75%       68.000000       0.000000     0.000000     0.000000     0.000000
# max      547.000000     552.000000   508.000000   480.000000   738.000000
#
#        PoolQC  Fence MiscFeature       MiscVal       MoSold       YrSold  \
# count       7    281          54   1460.000000  1460.000000  1460.000000
# unique      3      4           4           NaN          NaN          NaN
# top        Gd  MnPrv        Shed           NaN          NaN          NaN
# freq        3    157          49           NaN          NaN          NaN
# mean      NaN    NaN         NaN     43.489041     6.321918  2007.815753
# std       NaN    NaN         NaN    496.123024     2.703626     1.328095
# min       NaN    NaN         NaN      0.000000     1.000000  2006.000000
# 25%       NaN    NaN         NaN      0.000000     5.000000  2007.000000
# 50%       NaN    NaN         NaN      0.000000     6.000000  2008.000000
# 75%       NaN    NaN         NaN      0.000000     8.000000  2009.000000
# max       NaN    NaN         NaN  15500.000000    12.000000  2010.000000
#
#        SaleType SaleCondition      SalePrice
# count      1460          1460    1460.000000
# unique        9             6            NaN
# top          WD        Normal            NaN
# freq       1267          1198            NaN
# mean        NaN           NaN  180921.195890
# std         NaN           NaN   79442.502883
# min         NaN           NaN   34900.000000
# 25%         NaN           NaN  129975.000000
# 50%         NaN           NaN  163000.000000
# 75%         NaN           NaN  214000.000000
# max         NaN           NaN  755000.000000

# %%
df_housing.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# #### We begin by treating the missing values. To better analyze this ,we construct a table with the missing ratio for each variable that has missing values.

# %%
df_housing_missing = (df_housing.isnull().sum() / len(df_housing)) * 100
df_housing_missing = df_housing_missing.drop(df_housing_missing[df_housing_missing == 0].index).sort_values(ascending=False)

display(pd.DataFrame({'Missing Ratio' :df_housing_missing}))
# Out:
#               Missing Ratio
# PoolQC            99.520548
# MiscFeature       96.301370
# Alley             93.767123
# Fence             80.753425
# FireplaceQu       47.260274
# LotFrontage       17.739726
# GarageYrBlt        5.547945
# GarageType         5.547945
# GarageFinish       5.547945
# GarageQual         5.547945
# GarageCond         5.547945
# BsmtFinType2       2.602740
# BsmtExposure       2.602740
# BsmtFinType1       2.534247
# BsmtCond           2.534247
# BsmtQual           2.534247
# MasVnrArea         0.547945
# MasVnrType         0.547945
# Electrical         0.068493

# %% [markdown]
# #### Here we apply some strategies for inputting missing values, according to some hints we can get from the dataset description. For example, for some categorical variables a missing value represents a category like "None", and for some numerical variables it represents the value 0.

# %%
fill_none = ["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu", "GarageType", "GarageFinish", "GarageQual", "GarageCond",
            "BsmtExposure", "BsmtCond", "BsmtQual", "MasVnrType"]
for var in fill_none:
    df_housing[var] = df_housing[var].fillna("None")
    
fill_zero = ["GarageYrBlt", "BsmtFinType2", "BsmtFinType1", "MasVnrArea"]
for var in fill_zero:
    df_housing[var] = df_housing[var].fillna(0)

df_housing["LotFrontage"] = df_housing.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

df_housing['Electrical'] = df_housing['Electrical'].fillna(df_housing['Electrical'].mode()[0])

# %%
df_housing_missing = (df_housing.isnull().sum() / len(df_housing)) * 100
df_housing_missing = df_housing_missing.drop(df_housing_missing[df_housing_missing == 0].index).sort_values(ascending=False)

display(pd.DataFrame({'Missing Ratio' :df_housing_missing}))
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# #### Now we correct some data types, according to our interpretation of numerical and categorical variables in this dataset. We represent numerical values as float numbers and categorical as strings.

# %%
numeric_vars = ["LotFrontage", "LotArea", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF",
               "2ndFlrSF", "LowQualFinSF", "GrLivArea", "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch",
               "ScreenPorch", "PoolArea", "MiscVal", "SalePrice"]

categorical_vars = [v for v in df_housing.columns if v not in numeric_vars]

# %%
df_housing[numeric_vars] = df_housing[numeric_vars].astype(float)
df_housing[categorical_vars] = df_housing[categorical_vars].astype(str)

display(pd.DataFrame({"Data Type" :df_housing.dtypes}))
# Out:
#               Data Type
# MSSubClass       object
# MSZoning         object
# LotFrontage     float64
# LotArea         float64
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# OverallQual      object
# OverallCond      object
# YearBuilt        object
# YearRemodAdd     object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# MasVnrArea      float64
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinSF1      float64
# BsmtFinType2     object
# BsmtFinSF2      float64
# BsmtUnfSF       float64
# TotalBsmtSF     float64
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# 1stFlrSF        float64
# 2ndFlrSF        float64
# LowQualFinSF    float64
# GrLivArea       float64
# BsmtFullBath     object
# BsmtHalfBath     object
# FullBath         object
# HalfBath         object
# BedroomAbvGr     object
# KitchenAbvGr     object
# KitchenQual      object
# TotRmsAbvGrd     object
# Functional       object
# Fireplaces       object
# FireplaceQu      object
# GarageType       object
# GarageYrBlt      object
# GarageFinish     object
# GarageCars       object
# GarageArea      float64
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# WoodDeckSF      float64
# OpenPorchSF     float64
# EnclosedPorch   float64
# 3SsnPorch       float64
# ScreenPorch     float64
# PoolArea        float64
# PoolQC           object
# Fence            object
# MiscFeature      object
# MiscVal         float64
# MoSold           object
# YrSold           object
# SaleType         object
# SaleCondition    object
# SalePrice       float64

# %% [markdown]
# #### After finishing the data preparation, we then separate the original data frame into 3: one with the numerical variables, one with the categorical variables, and one with only the response variable. This will facilitate inputting data into the neural network for training, as will be explained later.

# %%
response = ["SalePrice"]

df_housing_numeric = df_housing[[var for var in numeric_vars if var not in response]]
df_housing_categotical = df_housing[categorical_vars]
df_housing_response = df_housing[response]

# %%
df_housing_numeric.describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     70.199658   10516.828082   103.117123   443.639726    46.549315
# std      22.431902    9981.264932   180.731373   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      60.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      70.000000    9478.500000     0.000000   383.500000     0.000000
# 75%      80.000000   11601.500000   164.250000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466      5.844521
# std     441.866955   438.705324   386.587738   436.528436     48.623081
# min       0.000000     0.000000   334.000000     0.000000      0.000000
# 25%     223.000000   795.750000   882.000000     0.000000      0.000000
# 50%     477.500000   991.500000  1087.000000     0.000000      0.000000
# 75%     808.000000  1298.250000  1391.250000   728.000000      0.000000
# max    2336.000000  6110.000000  4692.000000  2065.000000    572.000000
#
#          GrLivArea   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean   1515.463699   472.980137    94.244521    46.660274      21.954110
# std     525.480383   213.804841   125.338794    66.256028      61.119149
# min     334.000000     0.000000     0.000000     0.000000       0.000000
# 25%    1129.500000   334.500000     0.000000     0.000000       0.000000
# 50%    1464.000000   480.000000     0.000000    25.000000       0.000000
# 75%    1776.750000   576.000000   168.000000    68.000000       0.000000
# max    5642.000000  1418.000000   857.000000   547.000000     552.000000
#
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal
# count  1460.000000  1460.000000  1460.000000   1460.000000
# mean      3.409589    15.060959     2.758904     43.489041
# std      29.317331    55.757415    40.177307    496.123024
# min       0.000000     0.000000     0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      0.000000
# 50%       0.000000     0.000000     0.000000      0.000000
# 75%       0.000000     0.000000     0.000000      0.000000
# max     508.000000   480.000000   738.000000  15500.000000

# %%
df_housing_categotical.describe()
# Out:
#        MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# count        1460     1460   1460  1460     1460        1460      1460
# unique         15        5      2     3        4           4         2
# top            20       RL   Pave  None      Reg         Lvl    AllPub
# freq          536     1151   1454  1369      925        1311      1459
#
#        LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# count       1460      1460         1460       1460       1460     1460
# unique         5         3           25          9          8        5
# top       Inside       Gtl        NAmes       Norm       Norm     1Fam
# freq        1052      1382          225       1260       1445     1220
#
#        HouseStyle OverallQual OverallCond YearBuilt YearRemodAdd RoofStyle  \
# count        1460        1460        1460      1460         1460      1460
# unique          8          10           9       112           61         6
# top        1Story           5           5      2006         1950     Gable
# freq          726         397         821        67          178      1141
#
#        RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# count      1460        1460        1460       1460      1460      1460
# unique        8          15          16          4         4         5
# top     CompShg     VinylSd     VinylSd       None        TA        TA
# freq       1434         515         504        872       906      1282
#
#        Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# count        1460     1460     1460         1460         1460         1460
# unique          6        5        5            5            7            7
# top         PConc       TA       TA           No          Unf          Unf
# freq          647      649     1311          953          430         1256
#
#        Heating HeatingQC CentralAir Electrical BsmtFullBath BsmtHalfBath  \
# count     1460      1460       1460       1460         1460         1460
# unique       6         5          2          5            4            3
# top       GasA        Ex          Y      SBrkr            0            0
# freq      1428       741       1365       1335          856         1378
#
#        FullBath HalfBath BedroomAbvGr KitchenAbvGr KitchenQual TotRmsAbvGrd  \
# count      1460     1460         1460         1460        1460         1460
# unique        4        3            8            4           4           12
# top           2        0            3            1          TA            6
# freq        768      913          804         1392         735          402
#
#        Functional Fireplaces FireplaceQu GarageType GarageYrBlt GarageFinish  \
# count        1460       1460        1460       1460        1460         1460
# unique          7          4           6          7          98            4
# top           Typ          0        None     Attchd         0.0          Unf
# freq         1360        690         690        870          81          605
#
#        GarageCars GarageQual GarageCond PavedDrive PoolQC Fence MiscFeature  \
# count        1460       1460       1460       1460   1460  1460        1460
# unique          5          6          6          3      4     5           5
# top             2         TA         TA          Y   None  None        None
# freq          824       1311       1326       1340   1453  1179        1406
#
#        MoSold YrSold SaleType SaleCondition
# count    1460   1460     1460          1460
# unique     12      5        9             6
# top         6   2009       WD        Normal
# freq      253    338     1267          1198

# %%
df_housing_response.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %% [markdown]
# #### The only thing remaining is to create an initial representation for the categorical variables. With PyTorch, we can represent these as label-encoded. In this case, labels are just indices to map a given value between its initial categorical representation and the corresponding embedding representation.

# %%
label_encoders = {}
for var in categorical_vars:
    label_encoders[var] = LabelEncoder()
    df_housing_categotical[var] = label_encoders[var].fit_transform(df_housing_categotical[var])

# %%
df_housing_categotical.describe()
# Out:
#         MSSubClass     MSZoning       Street        Alley     LotShape  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.214384     3.028767     0.995890     0.993836     1.942466
# std       3.543318     0.632017     0.063996     0.249667     1.409156
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     3.000000     1.000000     1.000000     0.000000
# 50%       5.000000     3.000000     1.000000     1.000000     3.000000
# 75%       9.000000     3.000000     1.000000     1.000000     3.000000
# max      14.000000     4.000000     1.000000     2.000000     3.000000
#
#        LandContour    Utilities    LotConfig    LandSlope  Neighborhood  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean      2.777397     0.000685     3.019178     0.062329     12.251370
# std       0.707666     0.026171     1.622634     0.276232      6.013735
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       3.000000     0.000000     2.000000     0.000000      7.000000
# 50%       3.000000     0.000000     4.000000     0.000000     12.000000
# 75%       3.000000     0.000000     4.000000     0.000000     17.000000
# max       3.000000     1.000000     4.000000     2.000000     24.000000
#
#         Condition1   Condition2     BldgType   HouseStyle  OverallQual  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      2.031507     2.008219     0.493151     3.038356     5.986986
# std       0.868515     0.259040     1.198277     1.911305     1.431256
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     2.000000     0.000000     2.000000     5.000000
# 50%       2.000000     2.000000     0.000000     2.000000     6.000000
# 75%       2.000000     2.000000     0.000000     5.000000     7.000000
# max       8.000000     7.000000     4.000000     7.000000     9.000000
#
#        OverallCond    YearBuilt  YearRemodAdd    RoofStyle     RoofMatl  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      4.575342    72.975342     34.865753     1.410274     1.075342
# std       1.112799    28.852359     20.645407     0.834998     0.599127
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%       4.000000    55.000000     17.000000     1.000000     1.000000
# 50%       4.000000    74.000000     44.000000     1.000000     1.000000
# 75%       5.000000   101.000000     54.000000     1.000000     1.000000
# max       8.000000   111.000000     60.000000     5.000000     7.000000
#
#        Exterior1st  Exterior2nd   MasVnrType    ExterQual    ExterCond  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      9.624658    10.339726     1.762329     2.539726     3.733562
# std       3.197659     3.540570     0.614274     0.693995     0.731807
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       8.000000     8.000000     1.000000     2.000000     4.000000
# 50%      12.000000    13.000000     2.000000     3.000000     4.000000
# 75%      12.000000    13.000000     2.000000     3.000000     4.000000
# max      14.000000    15.000000     3.000000     3.000000     4.000000
#
#         Foundation     BsmtQual     BsmtCond  BsmtExposure  BsmtFinType1  \
# count  1460.000000  1460.000000  1460.000000   1460.000000   1460.000000
# mean      1.396575     2.724658     3.691096      2.310274      3.637671
# std       0.722394     1.278630     0.949616      1.165663      1.895727
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       1.000000     2.000000     4.000000      2.000000      2.000000
# 50%       1.000000     2.000000     4.000000      3.000000      3.000000
# 75%       2.000000     4.000000     4.000000      3.000000      6.000000
# max       5.000000     4.000000     4.000000      4.000000      6.000000
#
#        BsmtFinType2      Heating    HeatingQC   CentralAir   Electrical  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean       5.559589     1.036301     1.538356     0.934932     3.682192
# std        1.296332     0.295124     1.739524     0.246731     1.051301
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        6.000000     1.000000     0.000000     1.000000     4.000000
# 50%        6.000000     1.000000     0.000000     1.000000     4.000000
# 75%        6.000000     1.000000     4.000000     1.000000     4.000000
# max        6.000000     5.000000     4.000000     1.000000     4.000000
#
#        BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  \
# count   1460.000000   1460.000000  1460.000000  1460.000000   1460.000000
# mean       0.425342      0.057534     1.565068     0.382877      2.865753
# std        0.518911      0.238753     0.550916     0.502885      0.811875
# min        0.000000      0.000000     0.000000     0.000000      0.000000
# 25%        0.000000      0.000000     1.000000     0.000000      2.000000
# 50%        0.000000      0.000000     2.000000     0.000000      3.000000
# 75%        1.000000      0.000000     2.000000     1.000000      3.000000
# max        3.000000      2.000000     3.000000     2.000000      7.000000
#
#        KitchenAbvGr  KitchenQual  TotRmsAbvGrd   Functional   Fireplaces  \
# count   1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean       1.046575     2.339726      7.884247     5.749315     0.613014
# std        0.220338     0.830161      2.170814     0.979659     0.644666
# min        0.000000     0.000000      0.000000     0.000000     0.000000
# 25%        1.000000     2.000000      7.000000     6.000000     0.000000
# 50%        1.000000     3.000000      8.000000     6.000000     1.000000
# 75%        1.000000     3.000000      9.000000     6.000000     1.000000
# max        3.000000     3.000000     11.000000     6.000000     3.000000
#
#        FireplaceQu   GarageType  GarageYrBlt  GarageFinish   GarageCars  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      3.087671     2.485616    62.097945      1.876712     1.767123
# std       1.167523     1.933206    27.910915      1.191646     0.747315
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       2.000000     1.000000    45.000000      1.000000     1.000000
# 50%       3.000000     1.000000    64.000000      2.000000     2.000000
# 75%       3.000000     5.000000    88.000000      3.000000     2.000000
# max       5.000000     6.000000    97.000000      3.000000     4.000000
#
#         GarageQual   GarageCond   PavedDrive       PoolQC        Fence  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      4.716438     4.763014     1.856164     2.991096     3.504795
# std       0.898787     0.802670     0.496592     0.140703     1.082912
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     5.000000     2.000000     3.000000     4.000000
# 50%       5.000000     5.000000     2.000000     3.000000     4.000000
# 75%       5.000000     5.000000     2.000000     3.000000     4.000000
# max       5.000000     5.000000     2.000000     3.000000     4.000000
#
#        MiscFeature       MoSold       YrSold     SaleType  SaleCondition
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean      1.069178     6.492466     1.815753     7.513014       3.770548
# std       0.372102     2.975444     1.328095     1.552100       1.100854
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       1.000000     5.000000     1.000000     8.000000       4.000000
# 50%       1.000000     7.000000     2.000000     8.000000       4.000000
# 75%       1.000000     9.000000     3.000000     8.000000       4.000000
# max       4.000000    11.000000     4.000000     8.000000       5.000000

# %% [markdown]
# #### Now we split our prepared dataset into training, validation, and test sets. We will use 80% of the data for training, 10% for validation, and 10% for testing.

# %%
idx = list(range(df_housing_response.shape[0]))

np.random.seed(123)
np.random.shuffle(idx)

train_idx = idx[0:round(len(idx)*0.8)]
test_idx = idx[round(len(idx)*0.8):round(len(idx)*0.9)]
val_idx = idx[round(len(idx)*0.9):]

# %%
df_housing_num_train = df_housing_numeric.iloc[train_idx]
df_housing_cat_train = df_housing_categotical.iloc[train_idx]
df_housing_resp_train = df_housing_response.iloc[train_idx]

df_housing_num_test = df_housing_numeric.iloc[test_idx]
df_housing_cat_test = df_housing_categotical.iloc[test_idx]
df_housing_resp_test = df_housing_response.iloc[test_idx]

df_housing_num_val = df_housing_numeric.iloc[val_idx]
df_housing_cat_val = df_housing_categotical.iloc[val_idx]
df_housing_resp_val = df_housing_response.iloc[val_idx]

# %% [markdown]
# #### Thie function below is a generator for mini batches. In the training loop we define later, for each iteration we feed the neural network with a certain number of records from the training data given by the mini batch size we define. When creating a mini batch for the numerical variables, we also normalize then to help with the training convergence.

# %%
def get_batch(data_num, data_cat, data_resp, mb_size, scale_num):
    array_num = data_num.values.astype(np.float32)
    if scale_num:
        scaler = Normalizer()
        scaler.fit(array_num)
        array_num = scaler.transform(array_num)
    array_cat = data_cat.values.astype(np.long)
    array_resp = data_resp.values.astype(np.float32)
    shuffle = np.random.permutation(len(data_resp))
    start = 0
    array_num = array_num[shuffle]
    array_cat = array_cat[shuffle]
    array_resp = array_resp[shuffle]
    while start + mb_size <= len(data_resp):
        yield array_num[start:start+mb_size], array_cat[start:start+mb_size], array_resp[start:start+mb_size]
        start += mb_size

# %% [markdown]
# #### Here we define our model hypeparameters, which are used in the architecture and training process of our neural network.

# %%
numeric_vars = [var for var in numeric_vars if var not in response]

# %%
cat_dims = [int(df_housing_categotical[var].nunique()) for var in categorical_vars]
emb_dims = [min(50, (x + 1) // 2) for x in cat_dims]
hidden_layers = [512]
drop_rates = [0.25,0.25]
learning_rate = 0.005
lr_steps = [250]
lr_gamma = 0.1
mb_size = 32
num_iter = 250

# %% [markdown]
# #### Just to give us an idea of how each categorical variable is mapped to its corresponding embedding, here we print the size of each categorical variable and the corresponding size in the embedding space.

# %%
print(cat_dims, "\n\n", emb_dims)
# Out:
# [15, 5, 2, 3, 4, 4, 2, 5, 3, 25, 9, 8, 5, 8, 10, 9, 112, 61, 6, 8, 15, 16, 4, 4, 5, 6, 5, 5, 5, 7, 7, 6, 5, 2, 5, 4, 3, 4, 3, 8, 4, 4, 12, 7, 4, 6, 7, 98, 4, 5, 6, 6, 3, 4, 5, 5, 12, 5, 9, 6]
#
#  [8, 3, 1, 2, 2, 2, 1, 3, 2, 13, 5, 4, 3, 4, 5, 5, 50, 31, 3, 4, 8, 8, 2, 2, 3, 3, 3, 3, 3, 4, 4, 3, 3, 1, 3, 2, 2, 2, 2, 4, 2, 2, 6, 4, 2, 3, 4, 49, 2, 3, 3, 3, 2, 2, 3, 3, 6, 3, 5, 3]

# %% [markdown]
# #### This is the class defining the neural network architecture.
#
# #### We will implement the architecture described [here](https://yashuseth.blog/2018/07/22/pytorch-neural-network-for-tabular-data-with-categorical-embeddings/), but slightly modified because we will begin training locally with one hidden layer only. The architecture implemented here is illustrated by the following diagram:
#
# ![model architecture](model_architecture.png)
#
# #### Notice that we can easily introduce more hidden layers, just modifying the definition of the hyperparameter "hidden_layers" above.

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        self.embeddings = nn.ModuleList()
        for i in range(len(categorical_vars)):
            self.embeddings.append(nn.Embedding(cat_dims[i], emb_dims[i]))
        
        self.cat_dropout = nn.Dropout(drop_rates[0])
        
        self.num_batchnorm = nn.BatchNorm1d(len(numeric_vars))
        
        self.dense_block = nn.ModuleList()
        for l in range(len(hidden_layers)):
            if l == 0:
                self.dense_block.append(nn.Linear(sum(emb_dims)+len(numeric_vars), hidden_layers[l]))
                self.dense_block.append(nn.ReLU6())
                self.dense_block.append(nn.BatchNorm1d(hidden_layers[l]))
                self.dense_block.append(nn.Dropout(drop_rates[1]))
            if l > 0:
                self.dense_block.append(nn.Linear(hidden_layers[l-1], hidden_layers[l]))
                self.dense_block.append(nn.ReLU6())
                self.dense_block.append(nn.BatchNorm1d(hidden_layers[l]))
                self.dense_block.append(nn.Dropout(drop_rates[1]))
        
        self.dense = nn.Sequential(*self.dense_block)
        
        self.output = nn.Linear(hidden_layers[-1], 1)

    def forward(self, Xc_list, Xn):
        Xc_list = [self.embeddings[i](Xc_list[i]) for i in range(len(Xc_list))]
        Xc = torch.cat(Xc_list, dim=1)
        Xc = self.cat_dropout(Xc)
        Xn = self.num_batchnorm(Xn)
        X = torch.cat([Xc, Xn], dim=1)
        X = self.dense(X)
        X = self.output(X)
        return X

# %% [markdown]
# #### The loss function to be use here is the MAE (Mean Absolute Error).

# %%
class MAE_Loss(nn.Module):
    def __init__(self):
        super(MAE_Loss, self).__init__()
    
    def forward(self, X, Y):
        error = torch.abs(Y - X)
        loss = torch.mean(error)
        return loss

# %% [markdown]
# #### We then instantiate our model object and print the number of learnable parameters. We also define a flag, which indicates if there is a GPU available for training. If so, we can send our model object and all PyTorch tensors to be processed on the GPU.

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
gpu_available = torch.cuda.is_available()
print(gpu_available)
# Out:
# False

# %%
model = Model().cuda() if gpu_available else Model()
print("Number of learnable parameters: %d" % count_parameters(model))
# print(model)
# Out:
# Number of learnable parameters: 103383

# %% [markdown]
# #### Here we define aour model loss object, which we will try to minimize during training. We also define the optimizer and scheduler objects for the training process. Here we will use the Adam Optimization algorithm.

# %%
model_loss = MAE_Loss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=lr_steps, gamma=lr_gamma)

# %% [markdown]
# #### And finally we define the main training loop. We will iterate several times (also known as epochs) through the entire training data, performing forward and backward passes (known as backpropagation) through the network in order to minimize the loss function.
#
# #### For each of those iterations, we split the data into mini batches to perform the forward and backward passes, also keeping track of the model performance on the validation data.

# %%
train_losses = []
val_losses = []
num_mb = int(len(df_housing_num_train)/mb_size)

for n in range(num_iter):
    train_loss = 0
    val_loss = 0
    
    for k, (mb_Xn, mb_Xc, mb_Y) in enumerate(get_batch(df_housing_num_train, df_housing_cat_train, df_housing_resp_train, mb_size, True)):
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # convert data from numpy arrays to torch tensors and put them on GPU, if we have one available
        mb_Xn = torch.from_numpy(mb_Xn).cuda() if gpu_available else torch.from_numpy(mb_Xn)
        mb_Xc = [torch.from_numpy(mb_Xc[:,i]).long().cuda() if gpu_available else torch.from_numpy(mb_Xc[:,i]).long() for i in range(len(categorical_vars))]
        mb_Y = torch.from_numpy(mb_Y).cuda() if gpu_available else torch.from_numpy(mb_Y)
        
        # run forward + backward + optimize on a mini-batch
        outputs = model(mb_Xc, mb_Xn)
        loss = model_loss(outputs, mb_Y)
        loss.backward()
        optimizer.step()
        
        # update cost for each iteration
        train_loss += loss.data / num_mb
    
    # print and save the cost for each itaration
    print ("Train loss after itaration %i: %f" % (n, train_loss))
    train_losses.append(train_loss.cpu())
    
    # print actual and predicted values
    with torch.no_grad():
        model.eval()
        
        for k, (mb_Xn, mb_Xc, mb_Y) in enumerate(get_batch(df_housing_num_val, df_housing_cat_val, df_housing_resp_val, mb_size, True)):
            mb_Xn = torch.from_numpy(mb_Xn).cuda() if gpu_available else torch.from_numpy(mb_Xn)
            mb_Xc = [torch.from_numpy(mb_Xc[:,i]).long().cuda() if gpu_available else torch.from_numpy(mb_Xc[:,i]).long() for i in range(len(categorical_vars))]
            mb_Y = torch.from_numpy(mb_Y).cuda() if gpu_available else torch.from_numpy(mb_Y)
            outputs = model(mb_Xc, mb_Xn)
            loss = model_loss(outputs, mb_Y)
            val_loss += loss.data / num_mb
        print ("Validation loss after itaration %i: %f" % (n, val_loss))
        val_losses.append(val_loss.cpu())
        
        idx = np.random.choice(range(mb_size))
        actual = mb_Y[idx]
        Xc = [mb_Xc[i][idx].view(1) for i in range(len(categorical_vars))]
        Xn = mb_Xn[idx].view(1,len(numeric_vars))
        predicted = model(Xc, Xn)
        actual = actual.cpu().numpy().flatten()
        predicted = predicted.cpu().numpy().flatten()
        print("Actual: %s\tPredicted (Validation): %s\tError (Validation): %s\n\n" % (str(actual), str(predicted), str(np.abs(actual - predicted))))
        
        model.train()
        
    scheduler.step()
# Out:
# Train loss after itaration 0: 181000.890625
# Validation loss after itaration 0: 19959.773438
# Actual: [109500.]	Predicted (Validation): [10.774593]	Error (Validation): [109489.23]
#
#
# Train loss after itaration 1: 181168.109375
# Validation loss after itaration 1: 20265.181641
# Actual: [119000.]	Predicted (Validation): [50.116776]	Error (Validation): [118949.88]
#
#
# Train loss after itaration 2: 181158.968750
# Validation loss after itaration 2: 20344.308594
# Actual: [386250.]	Predicted (Validation): [139.36032]	Error (Validation): [386110.62]
#
#
# Train loss after itaration 3: 180771.062500
# Validation loss after itaration 3: 20500.566406
# Actual: [153500.]	Predicted (Validation): [280.27032]	Error (Validation): [153219.73]
#
#
# Train loss after itaration 4: 180996.031250
# Validation loss after itaration 4: 20588.640625
# Actual: [147000.]	Predicted (Validation): [471.3304]	Error (Validation): [146528.67]
#
#
# Train loss after itaration 5: 180715.734375
# Validation loss after itaration 5: 20608.089844
# Actual: [224000.]	Predicted (Validation): [689.3317]	Error (Validation): [223310.67]
#
#
# Train loss after itaration 6: 180431.750000
# Validation loss after itaration 6: 20261.675781
# Actual: [156000.]	Predicted (Validation): [971.5497]	Error (Validation): [155028.45]
#
#
# Train loss after itaration 7: 180110.906250
# Validation loss after itaration 7: 20050.679688
# Actual: [82000.]	Predicted (Validation): [1284.7499]	Error (Validation): [80715.25]
#
#
# Train loss after itaration 8: 179516.828125
# Validation loss after itaration 8: 20465.007812
# Actual: [127000.]	Predicted (Validation): [1669.4608]	Error (Validation): [125330.54]
#
#
# Train loss after itaration 9: 179114.156250
# Validation loss after itaration 9: 20358.894531
# Actual: [213000.]	Predicted (Validation): [2074.9768]	Error (Validation): [210925.02]
#
#
# Train loss after itaration 10: 178577.921875
# Validation loss after itaration 10: 20350.648438
# Actual: [326000.]	Predicted (Validation): [2517.2456]	Error (Validation): [323482.75]
#
#
# Train loss after itaration 11: 178264.500000
# Validation loss after itaration 11: 20258.531250
# Actual: [175900.]	Predicted (Validation): [3004.3987]	Error (Validation): [172895.6]
#
#
# Train loss after itaration 12: 177950.265625
# Validation loss after itaration 12: 20210.576172
# Actual: [154900.]	Predicted (Validation): [3564.9531]	Error (Validation): [151335.05]
#
#
# Train loss after itaration 13: 177404.234375
# Validation loss after itaration 13: 20001.138672
# Actual: [97000.]	Predicted (Validation): [4183.3193]	Error (Validation): [92816.68]
#
#
# Train loss after itaration 14: 176312.984375
# Validation loss after itaration 14: 19818.521484
# Actual: [185000.]	Predicted (Validation): [4718.815]	Error (Validation): [180281.19]
#
#
# Train loss after itaration 15: 175775.062500
# Validation loss after itaration 15: 19268.044922
# Actual: [153500.]	Predicted (Validation): [5441.492]	Error (Validation): [148058.5]
#
#
# Train loss after itaration 16: 175485.281250
# Validation loss after itaration 16: 19941.242188
# Actual: [129900.]	Predicted (Validation): [6173.708]	Error (Validation): [123726.29]
#
#
# Train loss after itaration 17: 174703.921875
# Validation loss after itaration 17: 19627.019531
# Actual: [55000.]	Predicted (Validation): [6800.909]	Error (Validation): [48199.09]
#
#
# Train loss after itaration 18: 173950.875000
# Validation loss after itaration 18: 19572.679688
# Actual: [133000.]	Predicted (Validation): [7557.5024]	Error (Validation): [125442.5]
#
#
# Train loss after itaration 19: 172595.953125
# Validation loss after itaration 19: 19852.572266
# Actual: [175000.]	Predicted (Validation): [8484.479]	Error (Validation): [166515.52]
#
#
# Train loss after itaration 20: 172180.671875
# Validation loss after itaration 20: 19238.003906
# Actual: [120500.]	Predicted (Validation): [9234.13]	Error (Validation): [111265.87]
#
#
# Train loss after itaration 21: 171089.687500
# Validation loss after itaration 21: 19267.027344
# Actual: [430000.]	Predicted (Validation): [10155.232]	Error (Validation): [419844.78]
#
#
# Train loss after itaration 22: 170319.093750
# Validation loss after itaration 22: 18998.810547
# Actual: [241500.]	Predicted (Validation): [11122.625]	Error (Validation): [230377.38]
#
#
# Train loss after itaration 23: 169467.187500
# Validation loss after itaration 23: 18958.367188
# Actual: [271000.]	Predicted (Validation): [12065.422]	Error (Validation): [258934.58]
#
#
# Train loss after itaration 24: 168854.093750
# Validation loss after itaration 24: 18588.035156
# Actual: [142500.]	Predicted (Validation): [13074.817]	Error (Validation): [129425.18]
#
#
# Train loss after itaration 25: 167574.296875
# Validation loss after itaration 25: 19456.632812
# Actual: [381000.]	Predicted (Validation): [14126.386]	Error (Validation): [366873.62]
#
#
# Train loss after itaration 26: 166653.140625
# Validation loss after itaration 26: 19102.662109
# Actual: [136905.]	Predicted (Validation): [15203.308]	Error (Validation): [121701.695]
#
#
# Train loss after itaration 27: 164969.250000
# Validation loss after itaration 27: 18882.609375
# Actual: [175500.]	Predicted (Validation): [16197.212]	Error (Validation): [159302.78]
#
#
# Train loss after itaration 28: 164520.265625
# Validation loss after itaration 28: 18540.218750
# Actual: [231500.]	Predicted (Validation): [17372.688]	Error (Validation): [214127.31]
#
#
# Train loss after itaration 29: 162904.281250
# Validation loss after itaration 29: 18186.792969
# Actual: [202900.]	Predicted (Validation): [18541.47]	Error (Validation): [184358.53]
#
#
# Train loss after itaration 30: 162129.312500
# Validation loss after itaration 30: 17562.710938
# Actual: [140000.]	Predicted (Validation): [19739.41]	Error (Validation): [120260.59]
#
#
# Train loss after itaration 31: 160962.015625
# Validation loss after itaration 31: 18083.343750
# Actual: [150900.]	Predicted (Validation): [21102.305]	Error (Validation): [129797.695]
#
#
# Train loss after itaration 32: 159817.046875
# Validation loss after itaration 32: 18558.138672
# Actual: [150000.]	Predicted (Validation): [22372.951]	Error (Validation): [127627.05]
#
#
# Train loss after itaration 33: 158434.125000
# Validation loss after itaration 33: 17588.730469
# Actual: [217000.]	Predicted (Validation): [23524.13]	Error (Validation): [193475.88]
#
#
# Train loss after itaration 34: 156994.718750
# Validation loss after itaration 34: 17126.796875
# Actual: [141000.]	Predicted (Validation): [24911.678]	Error (Validation): [116088.32]
#
#
# Train loss after itaration 35: 155662.218750
# Validation loss after itaration 35: 16920.246094
# Actual: [175900.]	Predicted (Validation): [26236.729]	Error (Validation): [149663.27]
#
#
# Train loss after itaration 36: 154024.625000
# Validation loss after itaration 36: 16714.814453
# Actual: [55000.]	Predicted (Validation): [27498.45]	Error (Validation): [27501.55]
#
#
# Train loss after itaration 37: 152814.687500
# Validation loss after itaration 37: 17241.339844
# Actual: [263435.]	Predicted (Validation): [29231.227]	Error (Validation): [234203.78]
#
#
# Train loss after itaration 38: 151314.890625
# Validation loss after itaration 38: 16927.730469
# Actual: [145000.]	Predicted (Validation): [30461.979]	Error (Validation): [114538.02]
#
#
# Train loss after itaration 39: 149840.921875
# Validation loss after itaration 39: 17311.970703
# Actual: [136500.]	Predicted (Validation): [32032.594]	Error (Validation): [104467.41]
#
#
# Train loss after itaration 40: 148006.921875
# Validation loss after itaration 40: 16662.419922
# Actual: [121000.]	Predicted (Validation): [33620.38]	Error (Validation): [87379.625]
#
#
# Train loss after itaration 41: 146602.953125
# Validation loss after itaration 41: 16000.651367
# Actual: [129000.]	Predicted (Validation): [35032.71]	Error (Validation): [93967.29]
#
#
# Train loss after itaration 42: 144714.843750
# Validation loss after itaration 42: 16367.751953
# Actual: [129000.]	Predicted (Validation): [36709.754]	Error (Validation): [92290.25]
#
#
# Train loss after itaration 43: 143645.765625
# Validation loss after itaration 43: 16148.832031
# Actual: [136905.]	Predicted (Validation): [38280.71]	Error (Validation): [98624.29]
#
#
# Train loss after itaration 44: 141987.843750
# Validation loss after itaration 44: 15857.966797
# Actual: [272000.]	Predicted (Validation): [39835.14]	Error (Validation): [232164.86]
#
#
# Train loss after itaration 45: 139699.140625
# Validation loss after itaration 45: 15745.229492
# Actual: [256000.]	Predicted (Validation): [41658.348]	Error (Validation): [214341.66]
# Train loss after itaration 46: 138686.531250
# Validation loss after itaration 46: 15450.384766
# Actual: [129000.]	Predicted (Validation): [43174.695]	Error (Validation): [85825.305]
#
#
# Train loss after itaration 47: 136870.562500
# Validation loss after itaration 47: 15858.322266
# Actual: [337000.]	Predicted (Validation): [44963.043]	Error (Validation): [292036.97]
#
#
# Train loss after itaration 48: 135280.187500
# Validation loss after itaration 48: 15443.063477
# Actual: [134432.]	Predicted (Validation): [46724.332]	Error (Validation): [87707.67]
#
#
# Train loss after itaration 49: 133891.484375
# Validation loss after itaration 49: 14893.394531
# Actual: [280000.]	Predicted (Validation): [48414.91]	Error (Validation): [231585.1]
#
#
# Train loss after itaration 50: 132015.609375
# Validation loss after itaration 50: 14711.773438
# Actual: [197000.]	Predicted (Validation): [50336.203]	Error (Validation): [146663.8]
#
#
# Train loss after itaration 51: 129793.101562
# Validation loss after itaration 51: 14677.248047
# Actual: [381000.]	Predicted (Validation): [52043.48]	Error (Validation): [328956.53]
#
#
# Train loss after itaration 52: 128303.281250
# Validation loss after itaration 52: 13968.237305
# Actual: [85000.]	Predicted (Validation): [53107.73]	Error (Validation): [31892.27]
#
#
# Train loss after itaration 53: 126241.070312
# Validation loss after itaration 53: 14200.277344
# Actual: [97000.]	Predicted (Validation): [55731.934]	Error (Validation): [41268.066]
#
#
# Train loss after itaration 54: 124438.984375
# Validation loss after itaration 54: 14262.562500
# Actual: [133000.]	Predicted (Validation): [57612.418]	Error (Validation): [75387.58]
#
#
# Train loss after itaration 55: 122574.218750
# Validation loss after itaration 55: 13566.857422
# Actual: [180000.]	Predicted (Validation): [59657.484]	Error (Validation): [120342.516]
#
#
# Train loss after itaration 56: 120553.609375
# Validation loss after itaration 56: 13727.826172
# Actual: [156000.]	Predicted (Validation): [61483.766]	Error (Validation): [94516.234]
#
#
# Train loss after itaration 57: 119121.781250
# Validation loss after itaration 57: 13350.947266
# Actual: [176000.]	Predicted (Validation): [63565.68]	Error (Validation): [112434.32]
#
#
# Train loss after itaration 58: 117097.929688
# Validation loss after itaration 58: 13026.732422
# Actual: [440000.]	Predicted (Validation): [65521.727]	Error (Validation): [374478.28]
#
#
# Train loss after itaration 59: 114570.984375
# Validation loss after itaration 59: 12704.968750
# Actual: [337000.]	Predicted (Validation): [67656.664]	Error (Validation): [269343.34]
#
#
# Train loss after itaration 60: 112982.421875
# Validation loss after itaration 60: 12950.667969
# Actual: [97000.]	Predicted (Validation): [68881.11]	Error (Validation): [28118.89]
#
#
# Train loss after itaration 61: 111110.101562
# Validation loss after itaration 61: 12431.708984
# Actual: [186500.]	Predicted (Validation): [71581.19]	Error (Validation): [114918.81]
#
#
# Train loss after itaration 62: 109443.117188
# Validation loss after itaration 62: 11695.112305
# Actual: [142500.]	Predicted (Validation): [73698.13]	Error (Validation): [68801.87]
#
#
# Train loss after itaration 63: 107191.414062
# Validation loss after itaration 63: 11744.187500
# Actual: [280000.]	Predicted (Validation): [75853.77]	Error (Validation): [204146.22]
#
#
# Train loss after itaration 64: 105139.250000
# Validation loss after itaration 64: 12231.504883
# Actual: [129000.]	Predicted (Validation): [77918.28]	Error (Validation): [51081.72]
#
#
# Train loss after itaration 65: 103146.226562
# Validation loss after itaration 65: 11783.010742
# Actual: [115000.]	Predicted (Validation): [79353.336]	Error (Validation): [35646.664]
#
#
# Train loss after itaration 66: 100765.648438
# Validation loss after itaration 66: 11538.925781
# Actual: [263435.]	Predicted (Validation): [82201.875]	Error (Validation): [181233.12]
#
#
# Train loss after itaration 67: 98755.406250
# Validation loss after itaration 67: 11231.725586
# Actual: [430000.]	Predicted (Validation): [84377.66]	Error (Validation): [345622.34]
#
#
# Train loss after itaration 68: 96740.085938
# Validation loss after itaration 68: 11436.207031
# Actual: [402861.]	Predicted (Validation): [86619.75]	Error (Validation): [316241.25]
#
#
# Train loss after itaration 69: 95190.382812
# Validation loss after itaration 69: 10410.196289
# Actual: [381000.]	Predicted (Validation): [89135.84]	Error (Validation): [291864.16]
#
#
# Train loss after itaration 70: 92267.835938
# Validation loss after itaration 70: 10102.080078
# Actual: [140000.]	Predicted (Validation): [91298.87]	Error (Validation): [48701.133]
#
#
# Train loss after itaration 71: 90400.843750
# Validation loss after itaration 71: 10337.578125
# Actual: [150900.]	Predicted (Validation): [93466.02]	Error (Validation): [57433.977]
#
#
# Train loss after itaration 72: 88492.156250
# Validation loss after itaration 72: 10156.285156
# Actual: [97000.]	Predicted (Validation): [88948.516]	Error (Validation): [8051.4844]
#
#
# Train loss after itaration 73: 86446.867188
# Validation loss after itaration 73: 9605.437500
# Actual: [139000.]	Predicted (Validation): [94758.75]	Error (Validation): [44241.25]
#
#
# Train loss after itaration 74: 84284.500000
# Validation loss after itaration 74: 9602.712891
# Actual: [147000.]	Predicted (Validation): [100795.45]	Error (Validation): [46204.547]
#
#
# Train loss after itaration 75: 82160.585938
# Validation loss after itaration 75: 9250.986328
# Actual: [193879.]	Predicted (Validation): [103436.04]	Error (Validation): [90442.96]
#
#
# Train loss after itaration 76: 80046.460938
# Validation loss after itaration 76: 9160.003906
# Actual: [147000.]	Predicted (Validation): [105734.92]	Error (Validation): [41265.08]
#
#
# Train loss after itaration 77: 77337.109375
# Validation loss after itaration 77: 9057.323242
# Actual: [222000.]	Predicted (Validation): [108590.055]	Error (Validation): [113409.945]
#
#
# Train loss after itaration 78: 75228.414062
# Validation loss after itaration 78: 8996.487305
# Actual: [140000.]	Predicted (Validation): [111189.8]	Error (Validation): [28810.203]
#
#
# Train loss after itaration 79: 73278.859375
# Validation loss after itaration 79: 8403.030273
# Actual: [153500.]	Predicted (Validation): [113962.44]	Error (Validation): [39537.562]
#
#
# Train loss after itaration 80: 70540.125000
# Validation loss after itaration 80: 8769.069336
# Actual: [143000.]	Predicted (Validation): [115518.555]	Error (Validation): [27481.445]
#
#
# Train loss after itaration 81: 68957.117188
# Validation loss after itaration 81: 8274.097656
# Actual: [133000.]	Predicted (Validation): [118025.266]	Error (Validation): [14974.734]
#
#
# Train loss after itaration 82: 66522.898438
# Validation loss after itaration 82: 7917.506836
# Actual: [359100.]	Predicted (Validation): [122553.8]	Error (Validation): [236546.2]
#
#
# Train loss after itaration 83: 64783.730469
# Validation loss after itaration 83: 8070.937500
# Actual: [230000.]	Predicted (Validation): [125466.83]	Error (Validation): [104533.17]
#
#
# Train loss after itaration 84: 62474.574219
# Validation loss after itaration 84: 7405.859863
# Actual: [203000.]	Predicted (Validation): [128796.97]	Error (Validation): [74203.03]
#
#
# Train loss after itaration 85: 60565.964844
# Validation loss after itaration 85: 7385.804688
# Actual: [206300.]	Predicted (Validation): [131883.9]	Error (Validation): [74416.09]
#
#
# Train loss after itaration 86: 57929.156250
# Validation loss after itaration 86: 7136.177246
# Actual: [55000.]	Predicted (Validation): [74250.93]	Error (Validation): [19250.93]
#
#
# Train loss after itaration 87: 56017.492188
# Validation loss after itaration 87: 6732.787109
# Actual: [145000.]	Predicted (Validation): [125094.805]	Error (Validation): [19905.195]
#
#
# Train loss after itaration 88: 54584.179688
# Validation loss after itaration 88: 6321.149414
# Actual: [142500.]	Predicted (Validation): [131473.03]	Error (Validation): [11026.969]
#
#
# Train loss after itaration 89: 52534.152344
# Validation loss after itaration 89: 5938.944336
# Actual: [155000.]	Predicted (Validation): [136680.78]	Error (Validation): [18319.219]
#
#
# Train loss after itaration 90: 50257.320312
# Validation loss after itaration 90: 5768.198242
# Actual: [127000.]	Predicted (Validation): [119951.98]	Error (Validation): [7048.0234]
#
#
# Train loss after itaration 91: 48718.656250
# Validation loss after itaration 91: 5523.916992
# Actual: [139000.]	Predicted (Validation): [122922.76]	Error (Validation): [16077.242]
# Train loss after itaration 92: 46602.238281
# Validation loss after itaration 92: 5484.496582
# Actual: [239500.]	Predicted (Validation): [156592.2]	Error (Validation): [82907.8]
#
#
# Train loss after itaration 93: 44642.523438
# Validation loss after itaration 93: 5376.197266
# Actual: [154900.]	Predicted (Validation): [141082.5]	Error (Validation): [13817.5]
#
#
# Train loss after itaration 94: 42513.226562
# Validation loss after itaration 94: 4772.326660
# Actual: [127000.]	Predicted (Validation): [120489.54]	Error (Validation): [6510.461]
#
#
# Train loss after itaration 95: 41444.664062
# Validation loss after itaration 95: 4851.808594
# Actual: [189000.]	Predicted (Validation): [167380.61]	Error (Validation): [21619.39]
#
#
# Train loss after itaration 96: 40473.371094
# Validation loss after itaration 96: 5012.649414
# Actual: [438780.]	Predicted (Validation): [172627.11]	Error (Validation): [266152.88]
#
#
# Train loss after itaration 97: 38547.054688
# Validation loss after itaration 97: 4966.899414
# Actual: [156000.]	Predicted (Validation): [164348.64]	Error (Validation): [8348.641]
#
#
# Train loss after itaration 98: 37470.910156
# Validation loss after itaration 98: 4768.012695
# Actual: [466500.]	Predicted (Validation): [179064.]	Error (Validation): [287436.]
#
#
# Train loss after itaration 99: 35524.769531
# Validation loss after itaration 99: 4193.493652
# Actual: [150000.]	Predicted (Validation): [100909.49]	Error (Validation): [49090.508]
#
#
# Train loss after itaration 100: 34575.730469
# Validation loss after itaration 100: 4456.140137
# Actual: [402861.]	Predicted (Validation): [185332.72]	Error (Validation): [217528.28]
#
#
# Train loss after itaration 101: 34111.171875
# Validation loss after itaration 101: 4353.898926
# Actual: [126175.]	Predicted (Validation): [122562.375]	Error (Validation): [3612.625]
#
#
# Train loss after itaration 102: 32306.964844
# Validation loss after itaration 102: 3983.692627
# Actual: [206300.]	Predicted (Validation): [173374.58]	Error (Validation): [32925.42]
#
#
# Train loss after itaration 103: 32326.529297
# Validation loss after itaration 103: 3946.334229
# Actual: [55000.]	Predicted (Validation): [85249.75]	Error (Validation): [30249.75]
#
#
# Train loss after itaration 104: 31183.931641
# Validation loss after itaration 104: 4167.081055
# Actual: [263435.]	Predicted (Validation): [197109.]	Error (Validation): [66326.]
#
#
# Train loss after itaration 105: 30738.337891
# Validation loss after itaration 105: 3960.453857
# Actual: [142500.]	Predicted (Validation): [142787.45]	Error (Validation): [287.45312]
#
#
# Train loss after itaration 106: 29396.199219
# Validation loss after itaration 106: 3619.138916
# Actual: [139000.]	Predicted (Validation): [108340.71]	Error (Validation): [30659.29]
#
#
# Train loss after itaration 107: 28835.322266
# Validation loss after itaration 107: 3851.550781
# Actual: [215200.]	Predicted (Validation): [207440.69]	Error (Validation): [7759.3125]
#
#
# Train loss after itaration 108: 28432.263672
# Validation loss after itaration 108: 3874.217041
# Actual: [213000.]	Predicted (Validation): [197893.3]	Error (Validation): [15106.703]
#
#
# Train loss after itaration 109: 27289.791016
# Validation loss after itaration 109: 3719.736572
# Actual: [156000.]	Predicted (Validation): [162512.52]	Error (Validation): [6512.5156]
#
#
# Train loss after itaration 110: 27035.322266
# Validation loss after itaration 110: 3160.346924
# Actual: [152000.]	Predicted (Validation): [137877.11]	Error (Validation): [14122.891]
#
#
# Train loss after itaration 111: 25971.951172
# Validation loss after itaration 111: 3557.479248
# Actual: [145000.]	Predicted (Validation): [155968.25]	Error (Validation): [10968.25]
#
#
# Train loss after itaration 112: 24502.722656
# Validation loss after itaration 112: 3486.544434
# Actual: [200000.]	Predicted (Validation): [138290.55]	Error (Validation): [61709.453]
#
#
# Train loss after itaration 113: 25188.673828
# Validation loss after itaration 113: 3170.235352
# Actual: [129000.]	Predicted (Validation): [135659.39]	Error (Validation): [6659.3906]
#
#
# Train loss after itaration 114: 24766.214844
# Validation loss after itaration 114: 3327.654541
# Actual: [139000.]	Predicted (Validation): [104203.24]	Error (Validation): [34796.758]
#
#
# Train loss after itaration 115: 24197.753906
# Validation loss after itaration 115: 3154.476807
# Actual: [202900.]	Predicted (Validation): [215235.48]	Error (Validation): [12335.484]
#
#
# Train loss after itaration 116: 24275.525391
# Validation loss after itaration 116: 3073.522949
# Actual: [176500.]	Predicted (Validation): [187021.19]	Error (Validation): [10521.1875]
#
#
# Train loss after itaration 117: 23776.843750
# Validation loss after itaration 117: 2948.352051
# Actual: [271000.]	Predicted (Validation): [240122.47]	Error (Validation): [30877.531]
#
#
# Train loss after itaration 118: 23069.060547
# Validation loss after itaration 118: 3144.432617
# Actual: [120500.]	Predicted (Validation): [100140.95]	Error (Validation): [20359.047]
#
#
# Train loss after itaration 119: 22859.275391
# Validation loss after itaration 119: 2967.946777
# Actual: [222000.]	Predicted (Validation): [244640.2]	Error (Validation): [22640.203]
#
#
# Train loss after itaration 120: 21820.839844
# Validation loss after itaration 120: 3109.086182
# Actual: [90350.]	Predicted (Validation): [142273.42]	Error (Validation): [51923.42]
#
#
# Train loss after itaration 121: 22223.660156
# Validation loss after itaration 121: 2879.980957
# Actual: [263435.]	Predicted (Validation): [233877.38]	Error (Validation): [29557.625]
#
#
# Train loss after itaration 122: 21810.929688
# Validation loss after itaration 122: 2862.814697
# Actual: [129900.]	Predicted (Validation): [115386.18]	Error (Validation): [14513.82]
#
#
# Train loss after itaration 123: 21534.576172
# Validation loss after itaration 123: 3077.495605
# Actual: [206300.]	Predicted (Validation): [187821.]	Error (Validation): [18479.]
#
#
# Train loss after itaration 124: 20055.222656
# Validation loss after itaration 124: 2986.531250
# Actual: [142500.]	Predicted (Validation): [145604.78]	Error (Validation): [3104.7812]
#
#
# Train loss after itaration 125: 19229.582031
# Validation loss after itaration 125: 2955.115234
# Actual: [233170.]	Predicted (Validation): [214351.23]	Error (Validation): [18818.766]
#
#
# Train loss after itaration 126: 20928.720703
# Validation loss after itaration 126: 2846.040039
# Actual: [271000.]	Predicted (Validation): [247609.11]	Error (Validation): [23390.89]
#
#
# Train loss after itaration 127: 19921.912109
# Validation loss after itaration 127: 2795.153809
# Actual: [149500.]	Predicted (Validation): [138318.58]	Error (Validation): [11181.422]
#
#
# Train loss after itaration 128: 19367.517578
# Validation loss after itaration 128: 2888.444580
# Actual: [126175.]	Predicted (Validation): [124923.09]	Error (Validation): [1251.9062]
#
#
# Train loss after itaration 129: 19534.812500
# Validation loss after itaration 129: 2728.367920
# Actual: [150000.]	Predicted (Validation): [112296.22]	Error (Validation): [37703.78]
#
#
# Train loss after itaration 130: 18989.759766
# Validation loss after itaration 130: 2627.735352
# Actual: [402861.]	Predicted (Validation): [274091.56]	Error (Validation): [128769.44]
#
#
# Train loss after itaration 131: 18772.416016
# Validation loss after itaration 131: 2873.736084
# Actual: [60000.]	Predicted (Validation): [89210.8]	Error (Validation): [29210.797]
#
#
# Train loss after itaration 132: 18928.027344
# Validation loss after itaration 132: 2688.305420
# Actual: [139000.]	Predicted (Validation): [112350.07]	Error (Validation): [26649.93]
#
#
# Train loss after itaration 133: 18625.277344
# Validation loss after itaration 133: 2653.176270
# Actual: [87500.]	Predicted (Validation): [88669.]	Error (Validation): [1169.]
#
#
# Train loss after itaration 134: 19476.554688
# Validation loss after itaration 134: 2760.238281
# Actual: [386250.]	Predicted (Validation): [275383.62]	Error (Validation): [110866.375]
#
#
# Train loss after itaration 135: 18171.433594
# Validation loss after itaration 135: 2723.462646
# Actual: [91000.]	Predicted (Validation): [102194.89]	Error (Validation): [11194.891]
#
#
# Train loss after itaration 136: 17054.583984
# Validation loss after itaration 136: 2779.049561
# Actual: [266500.]	Predicted (Validation): [213057.17]	Error (Validation): [53442.83]
#
#
# Train loss after itaration 137: 17665.535156
# Validation loss after itaration 137: 2606.178467
# Actual: [206300.]	Predicted (Validation): [192974.98]	Error (Validation): [13325.016]
# Train loss after itaration 138: 17765.060547
# Validation loss after itaration 138: 2590.516357
# Actual: [91000.]	Predicted (Validation): [102311.61]	Error (Validation): [11311.609]
#
#
# Train loss after itaration 139: 17479.220703
# Validation loss after itaration 139: 2650.580078
# Actual: [131000.]	Predicted (Validation): [143840.55]	Error (Validation): [12840.547]
#
#
# Train loss after itaration 140: 18989.787109
# Validation loss after itaration 140: 2409.463623
# Actual: [239500.]	Predicted (Validation): [229557.66]	Error (Validation): [9942.344]
#
#
# Train loss after itaration 141: 17662.478516
# Validation loss after itaration 141: 2722.675537
# Actual: [197900.]	Predicted (Validation): [161050.89]	Error (Validation): [36849.11]
#
#
# Train loss after itaration 142: 17866.046875
# Validation loss after itaration 142: 2709.389160
# Actual: [213000.]	Predicted (Validation): [200688.23]	Error (Validation): [12311.766]
#
#
# Train loss after itaration 143: 17536.162109
# Validation loss after itaration 143: 2653.638916
# Actual: [87500.]	Predicted (Validation): [86625.58]	Error (Validation): [874.4219]
#
#
# Train loss after itaration 144: 18236.136719
# Validation loss after itaration 144: 2540.771973
# Actual: [180000.]	Predicted (Validation): [189234.05]	Error (Validation): [9234.047]
#
#
# Train loss after itaration 145: 19171.148438
# Validation loss after itaration 145: 2396.487305
# Actual: [438780.]	Predicted (Validation): [298258.9]	Error (Validation): [140521.1]
#
#
# Train loss after itaration 146: 17280.062500
# Validation loss after itaration 146: 2527.791016
# Actual: [120500.]	Predicted (Validation): [102758.336]	Error (Validation): [17741.664]
#
#
# Train loss after itaration 147: 17037.175781
# Validation loss after itaration 147: 2685.487061
# Actual: [185000.]	Predicted (Validation): [201363.31]	Error (Validation): [16363.3125]
#
#
# Train loss after itaration 148: 18113.101562
# Validation loss after itaration 148: 2504.030762
# Actual: [190000.]	Predicted (Validation): [179293.38]	Error (Validation): [10706.625]
#
#
# Train loss after itaration 149: 17923.148438
# Validation loss after itaration 149: 2373.396973
# Actual: [90350.]	Predicted (Validation): [138891.47]	Error (Validation): [48541.47]
#
#
# Train loss after itaration 150: 17478.164062
# Validation loss after itaration 150: 2529.678223
# Actual: [101800.]	Predicted (Validation): [109323.96]	Error (Validation): [7523.961]
#
#
# Train loss after itaration 151: 17618.998047
# Validation loss after itaration 151: 2297.378174
# Actual: [114500.]	Predicted (Validation): [131125.42]	Error (Validation): [16625.422]
#
#
# Train loss after itaration 152: 15948.211914
# Validation loss after itaration 152: 2403.916992
# Actual: [85000.]	Predicted (Validation): [79349.84]	Error (Validation): [5650.1562]
#
#
# Train loss after itaration 153: 16512.292969
# Validation loss after itaration 153: 2518.390137
# Actual: [217000.]	Predicted (Validation): [243264.16]	Error (Validation): [26264.156]
#
#
# Train loss after itaration 154: 16410.218750
# Validation loss after itaration 154: 2419.703857
# Actual: [156932.]	Predicted (Validation): [172192.94]	Error (Validation): [15260.9375]
#
#
# Train loss after itaration 155: 17358.794922
# Validation loss after itaration 155: 2385.531982
# Actual: [203000.]	Predicted (Validation): [225298.08]	Error (Validation): [22298.078]
#
#
# Train loss after itaration 156: 17307.785156
# Validation loss after itaration 156: 2275.337646
# Actual: [144000.]	Predicted (Validation): [130346.6]	Error (Validation): [13653.398]
#
#
# Train loss after itaration 157: 17240.673828
# Validation loss after itaration 157: 2281.363770
# Actual: [149000.]	Predicted (Validation): [154200.73]	Error (Validation): [5200.7344]
#
#
# Train loss after itaration 158: 16284.387695
# Validation loss after itaration 158: 2233.439941
# Actual: [60000.]	Predicted (Validation): [86729.125]	Error (Validation): [26729.125]
#
#
# Train loss after itaration 159: 17045.312500
# Validation loss after itaration 159: 2279.336426
# Actual: [149500.]	Predicted (Validation): [136707.84]	Error (Validation): [12792.156]
#
#
# Train loss after itaration 160: 16008.337891
# Validation loss after itaration 160: 2425.358643
# Actual: [116050.]	Predicted (Validation): [97741.3]	Error (Validation): [18308.703]
#
#
# Train loss after itaration 161: 15482.042969
# Validation loss after itaration 161: 2477.817871
# Actual: [213000.]	Predicted (Validation): [204318.4]	Error (Validation): [8681.594]
#
#
# Train loss after itaration 162: 16065.966797
# Validation loss after itaration 162: 2282.041504
# Actual: [151000.]	Predicted (Validation): [169427.23]	Error (Validation): [18427.234]
#
#
# Train loss after itaration 163: 16827.931641
# Validation loss after itaration 163: 2374.216797
# Actual: [222000.]	Predicted (Validation): [260386.14]	Error (Validation): [38386.14]
#
#
# Train loss after itaration 164: 17421.648438
# Validation loss after itaration 164: 2433.468994
# Actual: [239686.]	Predicted (Validation): [206852.45]	Error (Validation): [32833.547]
#
#
# Train loss after itaration 165: 16629.927734
# Validation loss after itaration 165: 2458.484375
# Actual: [230000.]	Predicted (Validation): [200761.8]	Error (Validation): [29238.203]
#
#
# Train loss after itaration 166: 16562.312500
# Validation loss after itaration 166: 2407.888428
# Actual: [141000.]	Predicted (Validation): [115471.77]	Error (Validation): [25528.227]
#
#
# Train loss after itaration 167: 15874.677734
# Validation loss after itaration 167: 2215.863770
# Actual: [233230.]	Predicted (Validation): [224238.05]	Error (Validation): [8991.953]
#
#
# Train loss after itaration 168: 15575.422852
# Validation loss after itaration 168: 2465.185547
# Actual: [354000.]	Predicted (Validation): [309351.47]	Error (Validation): [44648.53]
#
#
# Train loss after itaration 169: 15241.478516
# Validation loss after itaration 169: 2330.368408
# Actual: [55000.]	Predicted (Validation): [74488.21]	Error (Validation): [19488.21]
#
#
# Train loss after itaration 170: 15994.680664
# Validation loss after itaration 170: 2471.571289
# Actual: [285000.]	Predicted (Validation): [291877.38]	Error (Validation): [6877.375]
#
#
# Train loss after itaration 171: 14614.481445
# Validation loss after itaration 171: 2322.031982
# Actual: [190000.]	Predicted (Validation): [177718.11]	Error (Validation): [12281.891]
#
#
# Train loss after itaration 172: 15247.557617
# Validation loss after itaration 172: 2413.961426
# Actual: [87500.]	Predicted (Validation): [87644.664]	Error (Validation): [144.66406]
#
#
# Train loss after itaration 173: 14405.540039
# Validation loss after itaration 173: 2479.768311
# Actual: [144900.]	Predicted (Validation): [136939.77]	Error (Validation): [7960.2344]
#
#
# Train loss after itaration 174: 16557.212891
# Validation loss after itaration 174: 2376.321533
# Actual: [153500.]	Predicted (Validation): [111988.94]	Error (Validation): [41511.062]
#
#
# Train loss after itaration 175: 16589.660156
# Validation loss after itaration 175: 2454.542969
# Actual: [217000.]	Predicted (Validation): [230857.66]	Error (Validation): [13857.656]
#
#
# Train loss after itaration 176: 14337.852539
# Validation loss after itaration 176: 2200.634766
# Actual: [185000.]	Predicted (Validation): [191225.53]	Error (Validation): [6225.5312]
#
#
# Train loss after itaration 177: 17228.916016
# Validation loss after itaration 177: 2378.342773
# Actual: [154900.]	Predicted (Validation): [136416.1]	Error (Validation): [18483.906]
#
#
# Train loss after itaration 178: 15520.158203
# Validation loss after itaration 178: 2371.960938
# Actual: [156000.]	Predicted (Validation): [165916.58]	Error (Validation): [9916.578]
#
#
# Train loss after itaration 179: 15983.120117
# Validation loss after itaration 179: 2281.238770
# Actual: [136500.]	Predicted (Validation): [166935.14]	Error (Validation): [30435.14]
#
#
# Train loss after itaration 180: 15358.176758
# Validation loss after itaration 180: 2367.550293
# Actual: [136500.]	Predicted (Validation): [167999.55]	Error (Validation): [31499.547]
#
#
# Train loss after itaration 181: 13920.973633
# Validation loss after itaration 181: 2337.933594
# Actual: [126175.]	Predicted (Validation): [128674.06]	Error (Validation): [2499.0625]
#
#
# Train loss after itaration 182: 15765.019531
# Validation loss after itaration 182: 2418.773438
# Actual: [254900.]	Predicted (Validation): [231284.02]	Error (Validation): [23615.984]
#
#
# Train loss after itaration 183: 14874.297852
# Validation loss after itaration 183: 2401.206299
# Actual: [175000.]	Predicted (Validation): [174274.19]	Error (Validation): [725.8125]
# Train loss after itaration 184: 16461.269531
# Validation loss after itaration 184: 2253.882324
# Actual: [139000.]	Predicted (Validation): [129231.09]	Error (Validation): [9768.906]
#
#
# Train loss after itaration 185: 14765.795898
# Validation loss after itaration 185: 2363.346680
# Actual: [272000.]	Predicted (Validation): [214599.48]	Error (Validation): [57400.516]
#
#
# Train loss after itaration 186: 15497.823242
# Validation loss after itaration 186: 2184.614258
# Actual: [119000.]	Predicted (Validation): [134141.19]	Error (Validation): [15141.1875]
#
#
# Train loss after itaration 187: 14710.094727
# Validation loss after itaration 187: 2269.472168
# Actual: [139000.]	Predicted (Validation): [113293.24]	Error (Validation): [25706.758]
#
#
# Train loss after itaration 188: 15649.614258
# Validation loss after itaration 188: 2361.757568
# Actual: [213000.]	Predicted (Validation): [203213.19]	Error (Validation): [9786.8125]
#
#
# Train loss after itaration 189: 14504.349609
# Validation loss after itaration 189: 2228.199707
# Actual: [158000.]	Predicted (Validation): [162164.55]	Error (Validation): [4164.547]
#
#
# Train loss after itaration 190: 15811.393555
# Validation loss after itaration 190: 2345.296387
# Actual: [150000.]	Predicted (Validation): [121807.92]	Error (Validation): [28192.078]
#
#
# Train loss after itaration 191: 14160.367188
# Validation loss after itaration 191: 2340.196533
# Actual: [205000.]	Predicted (Validation): [196288.28]	Error (Validation): [8711.719]
#
#
# Train loss after itaration 192: 14323.843750
# Validation loss after itaration 192: 2185.300537
# Actual: [120500.]	Predicted (Validation): [99173.51]	Error (Validation): [21326.492]
#
#
# Train loss after itaration 193: 14532.022461
# Validation loss after itaration 193: 2503.789062
# Actual: [141000.]	Predicted (Validation): [117525.1]	Error (Validation): [23474.898]
#
#
# Train loss after itaration 194: 16006.845703
# Validation loss after itaration 194: 2257.942627
# Actual: [224000.]	Predicted (Validation): [213956.47]	Error (Validation): [10043.531]
#
#
# Train loss after itaration 195: 14776.555664
# Validation loss after itaration 195: 2268.926270
# Actual: [155000.]	Predicted (Validation): [139179.06]	Error (Validation): [15820.9375]
#
#
# Train loss after itaration 196: 14128.627930
# Validation loss after itaration 196: 2201.072998
# Actual: [200000.]	Predicted (Validation): [132181.52]	Error (Validation): [67818.484]
#
#
# Train loss after itaration 197: 13870.736328
# Validation loss after itaration 197: 2398.607422
# Actual: [139000.]	Predicted (Validation): [140500.47]	Error (Validation): [1500.4688]
#
#
# Train loss after itaration 198: 15381.281250
# Validation loss after itaration 198: 2326.619629
# Actual: [214000.]	Predicted (Validation): [197277.66]	Error (Validation): [16722.344]
#
#
# Train loss after itaration 199: 14393.618164
# Validation loss after itaration 199: 2288.695801
# Actual: [155000.]	Predicted (Validation): [177784.47]	Error (Validation): [22784.469]
#
#
# Train loss after itaration 200: 15118.292969
# Validation loss after itaration 200: 2308.690430
# Actual: [180000.]	Predicted (Validation): [182293.12]	Error (Validation): [2293.125]
#
#
# Train loss after itaration 201: 14848.556641
# Validation loss after itaration 201: 2393.400146
# Actual: [144000.]	Predicted (Validation): [128316.82]	Error (Validation): [15683.18]
#
#
# Train loss after itaration 202: 14392.350586
# Validation loss after itaration 202: 2378.354492
# Actual: [126175.]	Predicted (Validation): [127324.05]	Error (Validation): [1149.0469]
#
#
# Train loss after itaration 203: 14063.578125
# Validation loss after itaration 203: 2164.108398
# Actual: [119000.]	Predicted (Validation): [128245.414]	Error (Validation): [9245.414]
#
#
# Train loss after itaration 204: 17354.773438
# Validation loss after itaration 204: 2101.956299
# Actual: [197000.]	Predicted (Validation): [216027.47]	Error (Validation): [19027.469]
#
#
# Train loss after itaration 205: 14356.208984
# Validation loss after itaration 205: 2387.379883
# Actual: [196500.]	Predicted (Validation): [186588.75]	Error (Validation): [9911.25]
#
#
# Train loss after itaration 206: 15382.546875
# Validation loss after itaration 206: 2527.005615
# Actual: [440000.]	Predicted (Validation): [307920.94]	Error (Validation): [132079.06]
#
#
# Train loss after itaration 207: 14982.033203
# Validation loss after itaration 207: 2226.736572
# Actual: [359100.]	Predicted (Validation): [284847.1]	Error (Validation): [74252.91]
#
#
# Train loss after itaration 208: 15989.255859
# Validation loss after itaration 208: 2110.050781
# Actual: [114500.]	Predicted (Validation): [132400.84]	Error (Validation): [17900.844]
#
#
# Train loss after itaration 209: 14100.794922
# Validation loss after itaration 209: 2273.519043
# Actual: [129900.]	Predicted (Validation): [116566.68]	Error (Validation): [13333.32]
#
#
# Train loss after itaration 210: 13857.593750
# Validation loss after itaration 210: 2238.477051
# Actual: [113000.]	Predicted (Validation): [124156.21]	Error (Validation): [11156.211]
#
#
# Train loss after itaration 211: 15173.250977
# Validation loss after itaration 211: 2247.375488
# Actual: [129000.]	Predicted (Validation): [136716.56]	Error (Validation): [7716.5625]
#
#
# Train loss after itaration 212: 15198.724609
# Validation loss after itaration 212: 2279.749512
# Actual: [215200.]	Predicted (Validation): [235174.53]	Error (Validation): [19974.531]
#
#
# Train loss after itaration 213: 14717.708984
# Validation loss after itaration 213: 2259.076416
# Actual: [430000.]	Predicted (Validation): [334963.44]	Error (Validation): [95036.56]
#
#
# Train loss after itaration 214: 16258.159180
# Validation loss after itaration 214: 2301.578613
# Actual: [139000.]	Predicted (Validation): [131879.03]	Error (Validation): [7120.9688]
#
#
# Train loss after itaration 215: 14508.495117
# Validation loss after itaration 215: 2176.463623
# Actual: [155000.]	Predicted (Validation): [137704.3]	Error (Validation): [17295.703]
#
#
# Train loss after itaration 216: 14573.406250
# Validation loss after itaration 216: 2192.601074
# Actual: [147000.]	Predicted (Validation): [154730.3]	Error (Validation): [7730.297]
#
#
# Train loss after itaration 217: 15203.275391
# Validation loss after itaration 217: 2122.890625
# Actual: [141000.]	Predicted (Validation): [119284.86]	Error (Validation): [21715.14]
#
#
# Train loss after itaration 218: 14665.871094
# Validation loss after itaration 218: 2254.542969
# Actual: [135500.]	Predicted (Validation): [134394.5]	Error (Validation): [1105.5]
#
#
# Train loss after itaration 219: 15510.197266
# Validation loss after itaration 219: 2276.441406
# Actual: [440000.]	Predicted (Validation): [319144.22]	Error (Validation): [120855.78]
#
#
# Train loss after itaration 220: 15574.910156
# Validation loss after itaration 220: 2423.705322
# Actual: [109500.]	Predicted (Validation): [99599.46]	Error (Validation): [9900.539]
#
#
# Train loss after itaration 221: 15112.424805
# Validation loss after itaration 221: 2228.881592
# Actual: [466500.]	Predicted (Validation): [357481.44]	Error (Validation): [109018.56]
#
#
# Train loss after itaration 222: 14641.505859
# Validation loss after itaration 222: 2184.218750
# Actual: [237500.]	Predicted (Validation): [199184.4]	Error (Validation): [38315.594]
#
#
# Train loss after itaration 223: 15142.900391
# Validation loss after itaration 223: 2101.488770
# Actual: [116050.]	Predicted (Validation): [99786.4]	Error (Validation): [16263.602]
#
#
# Train loss after itaration 224: 14825.771484
# Validation loss after itaration 224: 2248.914307
# Actual: [87500.]	Predicted (Validation): [88778.99]	Error (Validation): [1278.9922]
#
#
# Train loss after itaration 225: 14847.852539
# Validation loss after itaration 225: 2168.718750
# Actual: [402861.]	Predicted (Validation): [356365.03]	Error (Validation): [46495.97]
#
#
# Train loss after itaration 226: 13076.244141
# Validation loss after itaration 226: 2154.821289
# Actual: [189000.]	Predicted (Validation): [177463.31]	Error (Validation): [11536.6875]
#
#
# Train loss after itaration 227: 14595.830078
# Validation loss after itaration 227: 2123.775635
# Actual: [138500.]	Predicted (Validation): [136786.58]	Error (Validation): [1713.4219]
#
#
# Train loss after itaration 228: 13627.094727
# Validation loss after itaration 228: 2182.156006
# Actual: [188000.]	Predicted (Validation): [186824.98]	Error (Validation): [1175.0156]
#
#
# Train loss after itaration 229: 13246.828125
# Validation loss after itaration 229: 2252.806885
# Actual: [224900.]	Predicted (Validation): [193387.28]	Error (Validation): [31512.719]
# Train loss after itaration 230: 13895.002930
# Validation loss after itaration 230: 2279.874512
# Actual: [153500.]	Predicted (Validation): [105704.06]	Error (Validation): [47795.938]
#
#
# Train loss after itaration 231: 14393.308594
# Validation loss after itaration 231: 2156.057373
# Actual: [82000.]	Predicted (Validation): [97768.58]	Error (Validation): [15768.578]
#
#
# Train loss after itaration 232: 14698.314453
# Validation loss after itaration 232: 2242.216309
# Actual: [132500.]	Predicted (Validation): [142986.03]	Error (Validation): [10486.031]
#
#
# Train loss after itaration 233: 16268.564453
# Validation loss after itaration 233: 1975.089966
# Actual: [128500.]	Predicted (Validation): [124686.91]	Error (Validation): [3813.0938]
#
#
# Train loss after itaration 234: 15687.954102
# Validation loss after itaration 234: 2185.170654
# Actual: [100000.]	Predicted (Validation): [114600.19]	Error (Validation): [14600.1875]
#
#
# Train loss after itaration 235: 16988.906250
# Validation loss after itaration 235: 2156.803223
# Actual: [130000.]	Predicted (Validation): [137348.8]	Error (Validation): [7348.797]
#
#
# Train loss after itaration 236: 14144.737305
# Validation loss after itaration 236: 2159.507324
# Actual: [143000.]	Predicted (Validation): [131730.28]	Error (Validation): [11269.719]
#
#
# Train loss after itaration 237: 14795.895508
# Validation loss after itaration 237: 2189.645752
# Actual: [203000.]	Predicted (Validation): [223393.5]	Error (Validation): [20393.5]
#
#
# Train loss after itaration 238: 16991.705078
# Validation loss after itaration 238: 2164.296631
# Actual: [185000.]	Predicted (Validation): [190881.33]	Error (Validation): [5881.328]
#
#
# Train loss after itaration 239: 14776.166016
# Validation loss after itaration 239: 2148.039551
# Actual: [136500.]	Predicted (Validation): [163986.47]	Error (Validation): [27486.469]
#
#
# Train loss after itaration 240: 15251.616211
# Validation loss after itaration 240: 2230.898926
# Actual: [119000.]	Predicted (Validation): [131462.33]	Error (Validation): [12462.328]
#
#
# Train loss after itaration 241: 13328.232422
# Validation loss after itaration 241: 2249.354980
# Actual: [139000.]	Predicted (Validation): [111903.36]	Error (Validation): [27096.64]
#
#
# Train loss after itaration 242: 14539.525391
# Validation loss after itaration 242: 2041.719116
# Actual: [180000.]	Predicted (Validation): [188368.33]	Error (Validation): [8368.328]
#
#
# Train loss after itaration 243: 17084.685547
# Validation loss after itaration 243: 2263.843262
# Actual: [175000.]	Predicted (Validation): [172971.95]	Error (Validation): [2028.0469]
#
#
# Train loss after itaration 244: 14736.705078
# Validation loss after itaration 244: 2137.313965
# Actual: [150900.]	Predicted (Validation): [165134.89]	Error (Validation): [14234.891]
#
#
# Train loss after itaration 245: 14402.181641
# Validation loss after itaration 245: 2570.655273
# Actual: [87500.]	Predicted (Validation): [86210.22]	Error (Validation): [1289.7812]
#
#
# Train loss after itaration 246: 15164.699219
# Validation loss after itaration 246: 2267.747070
# Actual: [197000.]	Predicted (Validation): [206031.03]	Error (Validation): [9031.031]
#
#
# Train loss after itaration 247: 14994.612305
# Validation loss after itaration 247: 1946.951416
# Actual: [90350.]	Predicted (Validation): [137655.8]	Error (Validation): [47305.797]
#
#
# Train loss after itaration 248: 15830.791016
# Validation loss after itaration 248: 2206.355469
# Actual: [174000.]	Predicted (Validation): [173380.]	Error (Validation): [620.]
#
#
# Train loss after itaration 249: 16440.054688
# Validation loss after itaration 249: 2048.133301
# Actual: [359100.]	Predicted (Validation): [294687.16]	Error (Validation): [64412.844]

# %% [markdown]
# #### After finishing training, we save the learned model parameters to disk. We also save the data points of the losses for training and validation that were collected during the training loop.

# %%
torch.save(model.state_dict(), './model/housing_model_state_dict.pt')

pickle.dump(train_losses, open('./model/housing_train_losses.pickle', 'wb'))
pickle.dump(val_losses, open('./model/housing_val_losses.pickle', 'wb'))

# %% [markdown]
# #### Here we load the data and plot the losses computed for the training and validation data during the training process.

# %%
train_losses = pickle.load(open('./model/housing_train_losses.pickle', "rb"))

plt.figure()
plt.plot(train_losses)

# %%
val_losses = pickle.load(open('./model/housing_val_losses.pickle', "rb"))

plt.figure()
plt.plot(val_losses)

# %% [markdown]
# #### As the final step, we define a function to compute the MAE and print the corresponding results for the training, validation, and test sets.

# %%
def MAE(data_num, data_cat, data_resp):
    with torch.no_grad():
        errors = []
        for k, (mb_Xn, mb_Xc, mb_Y) in enumerate(get_batch(data_num, data_cat, data_resp, mb_size, True)):
            Xn = torch.from_numpy(mb_Xn).cuda() if gpu_available else torch.from_numpy(mb_Xn)
            Xc = [torch.from_numpy(mb_Xc[:,i]).long().cuda() if gpu_available else torch.from_numpy(mb_Xc[:,i]).long() for i in range(len(categorical_vars))]
            actual = torch.from_numpy(mb_Y).cuda() if gpu_available else torch.from_numpy(mb_Y)
            predicted = model(Xc, Xn)
            actual = actual.cpu().numpy().flatten()
            predicted = predicted.cpu().numpy().flatten()
            errors.append(np.abs(actual - predicted))
        return np.mean(errors)

# %%
model.load_state_dict(torch.load('./model/housing_model_state_dict.pt', map_location='cpu'))

model.eval()

print("MAE (Train): %f" % MAE(df_housing_num_train, df_housing_cat_train, df_housing_resp_train))
print("MAE (Validation): %f" % MAE(df_housing_num_val, df_housing_cat_val, df_housing_resp_val))
print("MAE (Test): %f" % MAE(df_housing_num_test, df_housing_cat_test, df_housing_resp_test))
# Out:
# MAE (Train): 7196.675781
# MAE (Validation): 20208.820312
# MAE (Test): 21131.195312
